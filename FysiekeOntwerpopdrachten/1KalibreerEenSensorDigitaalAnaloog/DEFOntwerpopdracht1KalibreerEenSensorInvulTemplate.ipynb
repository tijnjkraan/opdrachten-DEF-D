# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 1 invul template

# %% [markdown]
# ## Groepsgegevens en planning
#
# Aan het einde van deze ontwerpopdracht lever je als groep dit notebook gezamenlijk in via een pull request op Github en lever je een link naar dit pull request in op Brightspace. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan. Werk in de juiste branch.
#
# | Groep: 27     |  |
# | :-------------|:-------------|
# | Matthias Grablowitz| 6247261 |
# | Tijn Kraan| 6566499 |
# | Antony Rezende Bruinsma | 6039960 |
#
# | Planning Groep: 27     |Tijdstip / Tijdspanne  |
# |---|---|
# | Mijlpaal 1: Criteria opgesteld | 12:00 |
# | Mijlpaal 2: Eerste kalibratie meting gedaan| 15:00 |
# | Pauze 1| 12:30-13:30 |
# | Pauze 2| 15:30-16:00 |

# %% [markdown]
# ## *Opdracht 1*: Foto van alle schetsen.
#
# Zet de foto in dezelfde map als dit notebook en verander hieronder de naam in de naam van de foto.
#  ![Alt](schetsen-1.jpeg "schets student")
#   ![Alt](schetsen-2.jpeg "schets student")

# %% [markdown]
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat.** Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |druksensor | meten van gewicht van voorwerpen (weegschaal) | De Weegschaal moet tussen de 0-1kg kunnen meten met een sensitivity van 1g |
# |druksensor | meten wanneer je op je bureaustoel gaat zitten, als je gaat zitten start je computer op op jouw account | De sensor moet onderscheid kunnen maken tussen verschillende personen, (1kg verschil kunnen meten) |
# |Temperatuur sensor | Meten wanneer koffie drinkbaar is | Er moet tussen de 30-90 graden celcius gemeten worden met een sensitivity van 0.5 graden |
# |druksensor | Meten hoe hard iemand op een knop van een afstandsbediening drukt om sneller door te spoelen | De metingen moeten op het interval 0-0.25 kg bevinden, met tussenstappen van 0.025 kg |
# |Magneet |Draden door de muur heen meten|moet nauwkeurig aanwijzen waar bedrading zit, het interval moet 0-1 tesla zijn met tussenstappen van 0.01 tesla|
#
# Groep 27 heeft gekozen voor de druksensor van de afstandsbediening.

# %% [markdown]
# ## *Opdracht 3*: Foto van de schets van jouw meetopstelling in.
# We hebben een spanningsdeler gebouwd van een weerstand met 10k ohm en een druksensor met variabele weerstand. Door de variabele weerstand verandert ook de spanning, deze wordt gemeten na de druksensor
#  ![Alt](tekening-opstelling.jpeg "schets student")

# %% [markdown]
# ## *Opdracht 4*: Beantwoord de vragen
#
# 1. Welke variabelen ga je veranderen?
# 2. Over welk bereik ga je deze variabelen veranderen?
# 3. Wat ga je allemaal meten?
# 4. Hoeveel metingen ga je doen?
# 5. Ga je met deze keuzes kunnen evalueren of jouw sensor geschikt is voor de gekozen toepassingen?

# %% [markdown]
# 1. Het gewicht dat op de sensor ligt in kg
# 2. 0-250 g
# 3. tussenstappen van 25 g begint bij 0, tm 250 g
# 4. 11 metingen
# 5. Ja

# %% [markdown]
# ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Licht kort toe wat er in de foto te zien is.
#  ![Alt](opstelling.jpeg "meetopstelling student")

# %% [markdown]
# ## *Opdracht 6*: Meten en fitten, Leerdoel

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit 

arduino = np.array([0,357,393,431,447,470,493,525,543,560,567])
massa = np.array([0,25,50,75,100,125,150,175,200,225,250])/1000

def fit(x,a,b,c):
    return a*(x)**b
popt,pcov = curve_fit(fit,arduino,massa)


x_fit = np.linspace(min(arduino[1:]), max(arduino), 200)
y_fit = fit(x_fit, *popt)

plt.figure()
plt.errorbar(arduino,massa,5/1000,5,'k.',label='metingen')
plt.xscale('log')
plt.plot(x_fit,y_fit,label='fit lijn')
plt.xlabel('arduino meting')
plt.ylabel('massa [kg]')
plt.title('kalibreren van de arduino')
plt.legend()
plt.show()
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_18664\1671715757.py:9: RuntimeWarning: divide by zero encountered in power
#   return a*(x)**b
# C:\Users\matth\AppData\Local\Temp\ipykernel_18664\1671715757.py:10: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt,pcov = curve_fit(fit,arduino,massa)

# %% [markdown]
# ## *Opdracht 7*: Iteratie nodig?

# %% [markdown]
# De lijn die wij bij onze metingen gefit hebben lijkt te kloppen, daarom vonden wij het niet nodig om te itereren

# %% [markdown]
# ## *Opdracht 8*: Conclusie, leerdoel
#
# De sensor kan onderscheid maken tussen zacht, medium en hard drukken, het zou dus mogelijk zijn om drie verschillende doorspoel snelheden te hebben. Echter is de onzekerheid te groot bij een grotere drukkracht, waardoor de sensor geen goed onderscheid kan maken bij een kleiner drukverschil. Het zou dus niet mogelijk zijn om meer dan drie verschillende doorspoel standen te hebben. Dit blijkt ook uit de data, zo is het verschil tussen 100 en 250 gram nog goed te meten maar tussen 225 en 250 gram is nauwelijks te meten.

# %% [markdown]
# ## *Opdracht 9*: Aantonen leerdoelen beheersing
#
# Om aan te tonen dat je de leerdoelen beheerst, kopieer je hieronder alle cellen met 'leerdoel' in de titel. Zet zelf de cellen onder de goede kopjes. Mogelijk komt een cel bij meerdere leerdoelen terug.

# %% [markdown]
# ### Leerdoel 1: Simpele circuits (RC-circuit, spanningsdelers met sensoren) ontwerpen en fabriceren.

# %% [markdown]
# ## *Opdracht 3*: Foto van de schets van jouw meetopstelling in.
# We hebben een spanningsdeler gebouwd van een weerstand met 10k ohm en een druksensor met variabele weerstand. Door de variabele weerstand verandert ook de spanning, deze wordt gemeten na de druksensor
#  ![Alt](tekening-opstelling.jpeg "schets student")
#   ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Licht kort toe wat er in de foto te zien is.
#  ![Alt](opstelling.jpeg "meetopstelling student")

# %% [markdown]
# ### Leerdoel 2: Ontwerpeisen voor een opdracht SMART opstellen en vervolgens de ontwerpcyclus inrichten, rekening houdend met de randvoorwaarde van de opdracht.

# %% [markdown]
# ## *Opdracht 2*, MIJLPAAL, Leerdoel
# Vul onderstaande tabel in en geef aan met welke sensor je verder gaat.** Laat dit aan je TA zien.** Als je TA druk is: ga wel ondertussen door met de volgende stap.
#
# | Sensor | Toepassing | Criteria |
# |:---|:---|:---|
# |druksensor | meten van gewicht van voorwerpen (weegschaal) | De Weegschaal moet tussen de 0-1kg kunnen meten met een sensitivity van 1g |
# |druksensor | meten wanneer je op je bureaustoel gaat zitten, als je gaat zitten start je computer op op jouw account | De sensor moet onderscheid kunnen maken tussen verschillende personen, (1kg verschil kunnen meten) |
# |Temperatuur sensor | Meten wanneer koffie drinkbaar is | Er moet tussen de 30-90 graden celcius gemeten worden met een sensitivity van 0.5 graden |
# |druksensor | Meten hoe hard iemand op een knop van een afstandsbediening drukt om sneller door te spoelen | De metingen moeten op het interval 0-0.25 kg bevinden, met tussenstappen van 0.025 kg |
# |Magneet |Draden door de muur heen meten|moet nauwkeurig aanwijzen waar bedrading zit, het interval moet 0-1 tesla zijn met tussenstappen van 0.01 tesla|
#
# Groep 27 heeft gekozen voor de druksensor van de afstandsbediening.

# %% [markdown]
# ### Leerdoel 3: Voor een gegeven sensor & analoog-digitaal convertor en gegeven (of zelf gekozen) toepassing een kalibratie meting ontwerpen, inclusief het circuit om de sensor aan te sluiten op de analoog-digitaal convertor, de opstelling bouwen, en meetresultaten verwerken en concluderen of de combinatie van sensor en analoog-digitaal conversie geschikt is voor de toepassing.

# %% [markdown]
#  ## *Opdracht 5*: Foto van jouw meetopstelling in. Leerdoel.
# Licht kort toe wat er in de foto te zien is.
#  ![Alt](opstelling.jpeg "meetopstelling student")

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit 

arduino = np.array([0,357,393,431,447,470,493,525,543,560,567])
massa = np.array([0,25,50,75,100,125,150,175,200,225,250])/1000

def fit(x,a,b,c):
    return a*(x)**b
popt,pcov = curve_fit(fit,arduino,massa)


x_fit = np.linspace(min(arduino[1:]), max(arduino), 200)
y_fit = fit(x_fit, *popt)

plt.figure()
plt.errorbar(arduino,massa,5/1000,5,'k.',label='metingen')
plt.xscale('log')
plt.plot(x_fit,y_fit,label='fit lijn')
plt.xlabel('arduino meting')
plt.ylabel('massa [kg]')
plt.title('kalibreren van de arduino')
plt.legend()
plt.show()
# Out:
# C:\Users\matth\AppData\Local\Temp\ipykernel_18664\1573524621.py:9: RuntimeWarning: divide by zero encountered in power
#   return a*(x)**b
# C:\Users\matth\AppData\Local\Temp\ipykernel_18664\1573524621.py:10: OptimizeWarning: Covariance of the parameters could not be estimated
#   popt,pcov = curve_fit(fit,arduino,massa)

# %% [markdown]
# ## *Opdracht 8*: Conclusie, leerdoel
#
# De sensor kan onderscheid maken tussen zacht, medium en hard drukken, het zou dus mogelijk zijn om drie verschillende doorspoel snelheden te hebben. Echter is de onzekerheid te groot bij een grotere drukkracht, waardoor de sensor geen goed onderscheid kan maken bij een kleiner drukverschil. Het zou dus niet mogelijk zijn om meer dan drie verschillende doorspoel standen te hebben. Dit blijkt ook uit de data, zo is het verschil tussen 100 en 250 gram nog goed te meten maar tussen 225 en 250 gram is nauwelijks te meten.
