# %% [markdown]
# # DEF-D Fysieke Ontwerpopdracht 5 Invul template

# %% [markdown]
# ## Groep informatie
#
# Aan het einde van deze ontwerpopdracht lever je als groep één gezamenlijk notebook in. Zet jullie studienummers en namen in onderstaande tabel zodat wij zeker weten dat het groepsvormen goed is gegaan.

# %% [markdown]
# | Groep: 31     |  |
# | :-------------|:-------------|
# | Eline Serpenti | 6506690 |
# | Fiene Castillo Gosker| 6152678 |
# | Tijn Kraan    | 6566499 |

# %% [markdown]
# ## Opdracht 1: Planning.

# %% [markdown]
# | Planning Groep: 31     |Tijdstip / Tijdspanne  | door wie  |
# |---|---|---|
# | Arduino testen| 12:00 | Eline |
# | Ontwerp-eis berekenen| 12:00 | Fiene en Tijn|
# | Synthese | 30-45 min | hele groep |
# | Fabricage | 30-45 min | hele groep |
# | Begin synthese | 13:45 | ---|
# | Klaar Fabricage | 16:00 | ---|
# | Pauze 1| 12:45/ 13:45 | hele groep |
# | Pauze 2| 15:00/ 15:30 | hele groep |

# %% [markdown]
# Run onderstaande cel om alle benodigde libraries te laden. Mogelijk voeg je er zelf nog een aantal toe later vandaag.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import random
import time
import math

# %% [markdown]
# ## Opdracht 2a: Opsplitsen taak 1: Arduino
# Vul onderstaande tabel in:

# %% [markdown]
# | onderwerp    | antwoord  |
# |---|---|
# | hoe moeilijk (schaal 1 - 10) | 2 |
# | hoe lang voor één meting | 30 sec |
# | verwacht nauwkeurigheid meting | 30% |

# %% [markdown]
# ## Opdracht 2b: Opsplitsen taak 2: afleiding ontwerpeis

# %%
# Bereken hier je benodigde kantelfrequentie 
f = 5
f_0 = 2.5

# %% [markdown]
# 1. A_m/A_v = |1/(1-(f^2 /f_0^2))|
# 2. 1/3 = |1/(25/f_0^2)|
# 3. 25/f_0^2 = 4
# 4. f_0 = 2.5

# %%
# Voeg hier je plot in.

x = np.logspace(-1, 2, 100)  # Frequencies from 0.1 Hz to 100 Hz
H = np.absolute(1 / (1 - (5 / x)**2))  # Amplitude transfer function

plt.figure(figsize=(10, 6))
plt.loglog(x, H)
plt.xlabel('Frequentie (Hz)')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
# Bereken hier de minimale Delta-x waarbij je aan de eis van de opdracht voldoet.
g=9.81
omega_0 = 2 * math.pi * f_0
dx = g/(omega_0**2)
print(f"De minimale Delta-x is: {dx:.4f} m")
# Out:
# De minimale Delta-x is: 0.0398 m

# %% [markdown]
# ## Opdracht 3: Plot de grafiek.

# %%
# Voeg hier je plot in. Lees goed de opdracht wat er in de grafiek moet staan!
# Het is ook handig om je grafiek op te slaan, doe dat door met plt.savefig().

m = np.linspace(0, 1, 101)  # Massa's van 0.1 kg tot 10 kg  
C = m * g / dx
C_2 = m * g / (2*dx)
C_3 = m * g / (5*dx)
C_4 = m * g / (0.05)

plt.figure(figsize=(10, 6))
plt.plot(m, C, label='C voor dx')
plt.plot(m, C_2, label='C voor 2*dx')
plt.plot(m, C_3, label='C voor 5*dx')
plt.plot(m, C_4, label='C voor een dx van 0.05')
plt.xlabel('Massa (kg)')
plt.ylabel('Veerconstante (N/m)')
plt.title('Veerconstante als functie van massa')
plt.grid()
plt.legend()
plt.savefig('veerconstante_vs_massa.png')

# %% [markdown]
# ## Opdracht 4: Verander $\Delta x$.

# %% [markdown]
# We kunnen $\Delta x$ verhogen door:
#
# - veerconstante verlagen
# - massa verhogen
#
#
# Vul onderstaande aan. Geef eventueel met tekst aan waarom je hiervoor gekozen hebt, als extra informatie richting de nakijkers.
#
# Als groep gaan we mikken op een $\Delta x$ van: 5 centimeter

# %% [markdown]
# ## Opdracht 5: Schets.

# %% [markdown]
# ##### schets opstelling:
# <img src="Foto_opst.jpeg" width="400">

# %% [markdown]
# ## Opdracht 6: Beslissing evaluatie

# %% [markdown]
# Voldoet je ontwerp aan de eisen? Beantwoord de volgende vragen:
#
# ### Wat is de $\Delta x$ van je ontwerp?
#
# **5 centimeter**
#
# ### Wordt die $\Delta x$ behaald met je gekozen massa en veer?
#
# **Ja**
#
# ### hoeveel verder kan je massa-veer systeem nog uitrekken / indrukken?
# Wat is de limiet aan je veer / verend materiaal voordat het niet meer lineair reageert volgens de wet van Hooke?
#
# **20 centimeter**
#
# ### Is dat genoeg om straks metingen te kunnen doen?
# Hou er rekening mee dat je trillingen een amplitude in de orde grote van een paar centimeter gaan hebben, minder is met deze opzet moeilijk te realiseren.
#
# **Ja meer dan genoeg**
#
# ### Gaat je ontwerp dus voldoen aan de eis?
#
# **Ja**
#
# Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!
#
# Deze grafiek heb je later weer nodig om je gemeten punten aan toe te voegen. Ga daarna je massa-veer systeem daadwerkelijk bouwen.
#
# Als je hier negatief geantwoord hebt, kopieer onder deze cel dan alle cellen van Synthese tot en met Evaluation & decision en doorloop dat deel van het ontwerp proces nogmaals.

# %%
# Voeg hier je plot in.
#Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!

x = np.logspace(-1, 2, 101)  # Frequencies from 0.1 Hz to 100 Hz
H_eis = np.absolute(1 / (1 - (x / 2.5)**2))  # Amplitude transfer function for the design requirement
H_ontwerp = np.absolute(1 / (1 - (x / 2)**2))  # Amplitude transfer function for your design (replace with actual function)
 
plt.figure(figsize=(10, 6))
plt.loglog(x, H_eis, label='Eis Overdracht')
plt.loglog(x, H_ontwerp, label='Ontwerp Overdracht')
plt.xlabel('Frequentie (Hz)')
plt.ylabel('Amplitude')
plt.title('Amplitude Overdracht vs Frequentie')
plt.grid()
plt.legend()
plt.savefig('amplitude_overdracht.png')

# %% [markdown]
# ## Opdracht 7: Plotten maar

# %%
# Voeg hier je plots in.
f = np.array([9.4, 6.8, 4.1, 3.7])
A_1 = np.array([0.46, 0.51, 0.66, 0.37])
A_2 = np.array([7.13, 4.59, 2.05, 1.19])

H = (A_1 / A_2)

x= np.logspace(0, 1, 101)  # Frequencies from 0.1 Hz to 100 Hz
H_th = np.absolute(1 / (1 - (x / 2)**2))

plt.figure(figsize=(10, 6))
plt.errorbar(f, H,xerr=0.02*f, yerr=0.3*H, fmt='.', label='Gemeten Overdracht met Error Bars')
plt.loglog(x, H_th, '-', label='Theoretische Overdracht')
plt.xlabel('Frequentie (Hz)')
plt.ylabel('Amplitude Overdracht')
plt.legend()
plt.show()

# %% [markdown]
# ## Opdracht 8: Leerdoelen
# Voeg hieronder zelf kopjes toe om aan te geven wat bij welk leerdoel hoort.

# %%
# Als je met Python je resultaten wil laten zien: voeg hier je code in.

# %% [markdown]
# 1. Inzien dat de parameters in een differentiaalvergelijking ontwerpparameters zijn die een ontwerpruimte opspannen:

# %%
# Voeg hier je plot in.

x = np.logspace(-1, 2, 100)  # Frequencies from 0.1 Hz to 100 Hz
H = np.absolute(1 / (1 - (5 / x)**2))  # Amplitude transfer function

plt.figure(figsize=(10, 6))
plt.loglog(x, H)
plt.xlabel('Frequentie (Hz)')
plt.ylabel('Amplitude')
# Out:
# Text(0, 0.5, 'Amplitude')

# %%
# Voeg hier je plot in.
#Als je hier positief geantwoord heb, maak dan nog een keer een plot van amplitude overdracht (y-as) versus frequentie (x-as) zoals je hierboven ook al een keer gedaan heb, maar plot nu twee verschillende overdrachten in de grafiek: één die je al had: behorende bij de grens van de ontwerp-eis en één behorende bij je eigen ontwerp. Lees af dat je voor je ontwerp daadwerkelijk onder de eis grafiek zit op de kritieke frequentie!

x = np.logspace(-1, 2, 101)  # Frequencies from 0.1 Hz to 100 Hz
H_eis = np.absolute(1 / (1 - (x / 2.5)**2))  # Amplitude transfer function for the design requirement
H_ontwerp = np.absolute(1 / (1 - (x / 2)**2))  # Amplitude transfer function for your design (replace with actual function)
 
plt.figure(figsize=(10, 6))
plt.loglog(x, H_eis, label='Eis Overdracht')
plt.loglog(x, H_ontwerp, label='Ontwerp Overdracht')
plt.xlabel('Frequentie (Hz)')
plt.ylabel('Amplitude')
plt.title('Amplitude Overdracht vs Frequentie')
plt.grid()
plt.legend()
plt.savefig('amplitude_overdracht.png')

# %% [markdown]
# 2. Op basis van een differentiaal vergelijking een keuze maken voor parameters en die vervolgens kunnen vertalen in een fysiek ontwerp.

# %%
# Voeg hier je plot in. Lees goed de opdracht wat er in de grafiek moet staan!
# Het is ook handig om je grafiek op te slaan, doe dat door met plt.savefig().

m = np.linspace(0, 1, 101)  # Massa's van 0.1 kg tot 10 kg  
C = m * g / dx
C_2 = m * g / (2*dx)
C_3 = m * g / (5*dx)
C_4 = m * g / (0.05)

plt.figure(figsize=(10, 6))
plt.plot(m, C, label='C voor dx')
plt.plot(m, C_2, label='C voor 2*dx')
plt.plot(m, C_3, label='C voor 5*dx')
plt.plot(m, C_4, label='C voor een dx van 0.05')
plt.xlabel('Massa (kg)')
plt.ylabel('Veerconstante (N/m)')
plt.title('Veerconstante als functie van massa')
plt.grid()
plt.legend()
plt.savefig('veerconstante_vs_massa.png')

# %%
# Voeg hier je plots in.
f = np.array([9.4, 6.8, 4.1, 3.7])
A_1 = np.array([0.46, 0.51, 0.66, 0.37])
A_2 = np.array([7.13, 4.59, 2.05, 1.19])

H = (A_1 / A_2)

x= np.logspace(0, 1, 101)  # Frequencies from 0.1 Hz to 100 Hz
H_th = np.absolute(1 / (1 - (x / 2)**2))

plt.figure(figsize=(10, 6))
plt.errorbar(f, H,xerr=0.02*f, yerr=0.3*H, fmt='.', label='Gemeten Overdracht met Error Bars')
plt.loglog(x, H_th, '-', label='Theoretische Overdracht')
plt.xlabel('Frequentie (Hz)')
plt.ylabel('Amplitude Overdracht')
plt.legend()
plt.show()

# %% [markdown]
# #### Als je je figuren onderweg opgeslagen hebt, kan je ze hier invoegen:
# <img src="opstelling.jpeg" width="400">
# <img src="grafiek.png" width="400">
#
# <img src="amplitude_overdracht.png" width="400">
# <img src="veerconstante_vs_massa.png" width="400">
